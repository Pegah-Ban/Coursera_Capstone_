# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (London)

# %% [markdown]
# ## Topic: Finding the best place to open a new restaurant in London

# %% [markdown]
# ### 1- Introduction
# #### 1-1- Background

# %% [markdown]
# London is the capital and largest city of the United Kingdom. The city stands on the River Thames in the south-east of England. The restaurant and leisure industry in London is growing exponentially, every street is filled with every variety of restaurant, fast food place, pub, bar, etc; every type of food is available from the classic European cuisines, primarily Italian and French, to more exotic foods originating from Asia or South America. The demand in the culinary industry, has become very high, and as a result, has the extent of competition, in order to open a restaurant in a trendy area of this city, like the Shoreditch area.

# %% [markdown]
# #### 1-2- Business Problem
# Owning and running your own restaurant business is many people’s dream; at the same time, restaurants are a difficult business to own or operate. Many factors will contribute to where you decide your premises to be. It can be challenging to find a venue that will factor in all of your conditions, so you will likely have to compromise on a few things. However, the primary factor that you should consider is to find an appropriate location for this new restaurant and, as well as to be aware of the possible nearby and local competitors.
#
# In this work, we will implement the fundamental analysis, in order to find the optimal London Borough, in which the restaurant can be opened. This is conducted according to the criteria. That there are many additional factors regarding this, but the analysis can be done after choosing the Borough, and thus will not be done within the scope of this project.
#
# #### 1-3- Interest
#
# The target audience of this work would be anyone with an interest to get involved in the leisure and restaurant business and industry within the London districts.

# %% [markdown]
# ### 2- Data
# #### 2-1- Data Description
#
# To find a solution to the problem, and to be able to build a recommender model, first we consider the following:
#
# * Its geographical coordinates (i.e., latitude and longitude) to find out where exactly the venues are located.
#
# and
#
# * In order to access the location of a restaurant, its latitude and longitude should be known, so that we can point to its coordinates, and further create a map displaying all the restaurants with its labels, respectively.
#
# #### 2-2- Data Collection
#
#    Based on the criteria listed above, the following data can be utilized in this analysis:
# 1.	The deployment of *BeautifulSoup*, in order to extract the data from Wikipedia, and to further provide the relevant information on the [London boroughs](https://en.wikipedia.org/wiki/London_boroughs), i.e., also known as the local authority districts. Besides, the [local areas or neighbourhoods](https://en.wikipedia.org/wiki/List_of_areas_of_London) are considered for each borough for the detailed analysis.
# 2.	The [Foursquare](https://foursquare.com/) API, in order to extract the relevant information on the available restaurants, for a given neighborhood and borough in London. This API also provided information about the restaurant styles based on cuisine.
# 3.	The utilized data provided by the UK Government available at [data.london.gov.uk](https://data.london.gov.uk/dataset/london-borough-profiles) to get detailed insights on the London boroughs.

# %% [markdown]
# ### 3- Methodology

# %% [markdown]
# #### Installing and Importing Python Libraries and Dependencies

# %%
# !conda install -c conda-forge folium
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_1         2.1 MB  conda-forge
#     folium-0.11.0              |             py_0          61 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.11.0-py_0       conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2020.6.20-py36_0              --> 2020.6.20-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_1        conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.6.24-0                   --> 2020.6.20-hecda079_0     conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# folium-0.11.0        | 61 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

import folium # map rendering library

from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.cluster import KMeans


import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# ### Data Extraction and Cleaning¶
#
# ##### Utilizing BeautifulSoup in order to scraping list of postal codes of given wikipedia page. Link: https://en.wikipedia.org/wiki/List_of_areas_of_London

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_areas_of_London').text

soup = BeautifulSoup(source,'lxml')
My_Table = soup.find('table',{'class':'wikitable sortable'})

# First two columns
headers = My_Table.find_all('th')
headers = [th.text.strip() for th in headers]
headers = headers[:2]
x = headers[1].split('\xa0')
x = ' '.join(x)
headers.pop()
headers.append(x)
headers
# Out:
# ['Location', 'London borough']

# %%
rows = []
for tr in My_Table.find_all('tr'):
    tds = tr.find_all('td')
    rows.append(tds)
    if not tds:
        continue
del rows[0]

col_0 = []
for i in range(len(rows)):
    col_0.append(rows[i][0])
Locations = []
for location in col_0:
    Locations.append(location.text)
for index, ele in enumerate(Locations):
    if '(' in ele:
        Locations[index] = Locations[index].split('(')[0]
for index, ele in enumerate(Locations):
    if ',' in ele:
        Locations[index] = Locations[index].split(',')[0]        
    
col_1 = []
for i in range(len(rows)):
    col_1.append(rows[i][1])
Boroughs = []
for borough in col_1:
    Boroughs.append(borough.text)
for index, ele in enumerate(Boroughs):
    if '[' in ele:
        Boroughs[index] = Boroughs[index].split('[')[0]
for index, ele in enumerate(Boroughs):
    if ',' in ele:
        Boroughs[index] = Boroughs[index].split(',')[0]

# %%
len(Locations)
# Out:
# 533

# %% [markdown]
# ##### Now it is time to convert the headers into latitude and longitude values:

# %%
headers.append('Latitude')
headers.append('Longitude')
if len(headers)>4:
    headers = headers[:4]

df = pd.DataFrame(list(zip(Locations, Boroughs, latitude, longitude)), 
               columns = headers) 
df.head()
# Out:
#       Location London borough Latitude  Longitude
# 0   Abbey Wood         Bexley    51.49   0.132891
# 1        Acton         Ealing  51.5081  -0.273261
# 2    Addington        Croydon  51.3586 -0.0316347
# 3   Addiscombe        Croydon  51.3797 -0.0742821
# 4  Albany Park         Bexley  51.4354   0.125965

# %%
#Delete rows with locations not having latitude and longitude values
df = df[df.Latitude != "Not Found"]
df.shape
# Out:
# (124, 4)

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df['London borough'].unique()),
        df.shape[0]
    )
)
# Out:
# The dataframe has 31 boroughs and 124 neighborhoods.

# %%
address = 'London, England'

geolocator = Nominatim(user_agent="london_explorer")
location = geolocator.geocode(address)
lat_e = location.latitude
long_e = location.longitude
print('The geograpical coordinate of London City are {}, {}.'.format(lat_e, long_e))
# Out:
# The geograpical coordinate of London City are 51.5073219, -0.1276474.

# %% [markdown]
# #### Map of London

# %%
# create map of London using latitude and longitude values
map_london = folium.Map(location=[lat_e, long_e], zoom_start=10)

# add markers to map
for lat, lng, borough, location in zip(df['Latitude'], df['Longitude'], df['London borough'], df['Location']):
    label = '{}, {}'.format(location, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)  
    
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### In this section outliers would be deleted from the data with use of longitude values
#
#  The extreme left location to be considered for study is Longford, Hillington with longitude value of '-0.490805'. Similarly, the extreme right is North Ockendon, Havering with longitude value of '0.293698'. So, any longitude value less then '-0.5' and greater then '0.3' will not be considered for evaluation.

# %%
# df[df.Longitude > -0.5 & df.Longitude < 0.3]
df = df[df.Longitude > -0.5]
df = df[df.Longitude < 0.3]

# %%
# create map of London using latitude and longitude values
map_london = folium.Map(location=[lat_e, long_e], zoom_start=10)

# add markers to map
for lat, lng, borough, location in zip(df['Latitude'], df['Longitude'], df['London borough'], df['Location']):
    label = '{}, {}'.format(location, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)  
    
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Let's setup FourSquare credentials to explore the neighborhoods and segment them

# %%
LIMIT = 200
CLIENT_ID = '1RRKTMG4TT23GGB11RXDZ53CD251M2DDTTPQC3EF0EWZO1WK' # your Foursquare ID
CLIENT_SECRET = 'HHY3W52GYQT2TGTVJ00OOV2R5CB13CSSPA0JFXZQY5EZ31P0' # your Foursquare Secret
VERSION = '20191116' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 1RRKTMG4TT23GGB11RXDZ53CD251M2DDTTPQC3EF0EWZO1WK
# CLIENT_SECRET:HHY3W52GYQT2TGTVJ00OOV2R5CB13CSSPA0JFXZQY5EZ31P0

# %% [markdown]
# #### Now, let's get the London's top venues, to do so, first,  GET request URL would be created:

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### The above function would be utilized on each neighborhood and a new dataframe under the name 'London_venues' would be developed.

# %%
London_venues = getNearbyVenues(names=df['Location'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude'])
# Out:
# Abbey Wood
# Acton
# Addington
# Addiscombe
# Albany Park
# Aldgate
# Aldwych
# Alperton
# Anerley
# Angel
# Aperfield
# Archway
# Ardleigh Green
# Arkley
# Arnos Grove
# Balham
# Bankside
# Barbican
# Barking
# Barkingside
# Barnehurst
# Barnes
# Barnes Cray
# Barnet Gate
# Barnet
# Barnsbury
# Battersea
# Bayswater
# Beckenham
# Beckton
# Becontree
# Becontree Heath
# Beddington
# Bedford Park
# Belgravia
# Bellingham
# Belmont
# Belmont
# Belsize Park
# Belvedere
# Bermondsey
# Berrylands
# Bethnal Green
# Bexley
# Bexleyheath
# Bickley
# Biggin Hill
# Blackfen
# Blackfriars
# Blackheath
# Blackheath Royal Standard
# Blackwall
# Blendon
# Bloomsbury
# Botany Bay
# Bounds Green
# Bow
# Bowes Park
# Brentford
# Brent Cross
# Brent Park
# Brimsdown
# Brixton
# Brockley
# Bromley
# Bromley
# Bromley Common
# Brondesbury
# Brunswick Park
# Bulls Cross
# Burnt Oak
# Burroughs
# Camberwell
# Cambridge Heath
# Camden Town
# Canary Wharf
# Canning Town
# Canonbury
# Carshalton
# Castelnau
# Castle Green
# Catford
# Chadwell Heath
# Chalk Farm
# Charing Cross
# Charlton
# Chase Cross
# Cheam
# Chelsea
# Chelsfield
# Chessington
# Childs Hill
# Chinatown
# Chinbrook
# Chingford
# Chislehurst
# Chiswick
# Church End
# Clapham
# Clerkenwell
# Cockfosters
# Colindale
# Collier Row
# Colliers Wood
# Colney Hatch
# Colyers
# Coney Hall
# Coombe
# Coombe
# Coulsdon
# Covent Garden
# Cowley
# Cranford
# Cranham
# Crayford
# Creekmouth
# Crews Hill
# Cricklewood
# Crofton Park
# Crook Log
# Crossness
# Crouch End
# Croydon

# %%
print(London_venues.shape)
London_venues.head()
# Out:
# (3137, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0   Abbey Wood              51.489962                0.132891
# 1   Abbey Wood              51.489962                0.132891
# 2   Abbey Wood              51.489962                0.132891
# 3   Abbey Wood              51.489962                0.132891
# 4        Acton              51.508140               -0.273261
#
#                                  Venue  Venue Latitude  Venue Longitude  \
# 0                         Lesnes Abbey       51.489526         0.125839
# 1  B11 Bus Stop , Alsike Railway Track       51.492292         0.135419
# 2                           Abbey Cafe       51.492258         0.136148
# 3                    Lesnes Abbey Park       51.488385         0.127888
# 4                    London Star Hotel       51.509624        -0.272456
#
#   Venue Category
# 0  Historic Site
# 1       Bus Stop
# 2           Café
# 3           Park
# 4          Hotel

# %%
# Number of venues for each nrighborhood
London_venues.groupby('Neighborhood')
print('There are {} uniques categories.'.format(len(London_venues['Venue Category'].unique())))
# Out:
# There are 298 uniques categories.

# %% [markdown]
# ### Explore Neighborhoods in London

# %% [markdown]
# #### Restaurants would be extracted from venue category list as  "London_restaurants"

# %%
London_restaurants = London_venues[London_venues['Venue Category'].str.contains("Restaurant")]
print('There are {} unique categories available in London.'.format(len(London_restaurants['Venue Category'].unique())))
# Out:
# There are 63 unique categories available in London.

# %% [markdown]
# ####  Creating a function to repeat the same process to all the neighborhoods in London.

# %%
# one hot encoding
London_onehot = pd.get_dummies(London_restaurants[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
London_onehot['Neighborhood'] = London_restaurants['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [London_onehot.columns[-1]] + list(London_onehot.columns[:-1])
London_onehot = London_onehot[fixed_columns]

London_onehot.head()
# Out:
#    Neighborhood  Afghan Restaurant  African Restaurant  American Restaurant  \
# 10        Acton                  0                   0                    0
# 17        Acton                  0                   0                    0
# 27    Addington                  0                   0                    0
# 35   Addiscombe                  0                   0                    0
# 37   Addiscombe                  0                   0                    0
#
#     Arepa Restaurant  Argentinian Restaurant  Asian Restaurant  \
# 10                 0                       0                 0
# 17                 0                       0                 0
# 27                 0                       0                 0
# 35                 0                       0                 0
# 37                 0                       0                 0
#
#     Austrian Restaurant  Brazilian Restaurant  Cantonese Restaurant  ...  \
# 10                    0                     0                     0  ...
# 17                    0                     0                     0  ...
# 27                    0                     0                     0  ...
# 35                    0                     0                     0  ...
# 37                    0                     0                     0  ...
#
#     Sushi Restaurant  Szechuan Restaurant  Tapas Restaurant  Thai Restaurant  \
# 10                 0                    0                 0                0
# 17                 0                    0                 0                0
# 27                 0                    0                 0                0
# 35                 0                    0                 0                0
# 37                 0                    0                 0                0
#
#     Turkish Restaurant  Udon Restaurant  Vegetarian / Vegan Restaurant  \
# 10                   0                0                              0
# 17                   0                0                              0
# 27                   0                0                              0
# 35                   0                0                              0
# 37                   0                0                              0
#
#     Veneto Restaurant  Vietnamese Restaurant  Xinjiang Restaurant
# 10                  0                      0                    0
# 17                  0                      0                    0
# 27                  0                      0                    0
# 35                  0                      0                    0
# 37                  0                      0                    0
#
# [5 rows x 64 columns]

# %%
print('There are {} restaurants in London with {} different style of cuisines.'.format(London_onehot.shape[0],(London_onehot.shape[1]-1)))
# Out:
# There are 700 restaurants in London with 63 different style of cuisines.

# %%
London_grouped = London_onehot.groupby('Neighborhood').mean().reset_index()
London_grouped.shape
# Out:
# (92, 64)

# %% [markdown]
# #### Now Top 3 restaurants for each Neighborhood can be located based on cuisine:

# %%
num_top_rest = 3

for hood in London_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = London_grouped[London_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_rest))
    print('\n')
# Out:
# ----Acton----
#                   venue  freq
# 0    Chinese Restaurant   0.5
# 1  Fast Food Restaurant   0.5
# 2     Afghan Restaurant   0.0
#
#
# ----Addington----
#                  venue  freq
# 0   English Restaurant   1.0
# 1    Korean Restaurant   0.0
# 2  Lebanese Restaurant   0.0
#
#
# ----Addiscombe----
#                   venue  freq
# 0  Fast Food Restaurant  0.67
# 1    Chinese Restaurant  0.33
# 2     Afghan Restaurant  0.00
#
#
# ----Albany Park----
#                venue  freq
# 0  Indian Restaurant   1.0
# 1  Afghan Restaurant   0.0
# 2  Korean Restaurant   0.0
#
#
# ----Aldgate----
#                 venue  freq
# 0   Indian Restaurant   0.1
# 1  Italian Restaurant   0.1
# 2          Restaurant   0.1
#
#
# ----Aldwych----
#                  venue  freq
# 0           Restaurant  0.25
# 1  Japanese Restaurant  0.10
# 2   English Restaurant  0.10
#
#
# ----Alperton----
#                        venue  freq
# 0          Indian Restaurant  0.50
# 1           Asian Restaurant  0.25
# 2  Middle Eastern Restaurant  0.25
#
#
# ----Anerley----
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1     Afghan Restaurant   0.0
# 2     Korean Restaurant   0.0
#
#
# ----Angel----
#                       venue  freq
# 0  Mediterranean Restaurant   0.1
# 1     Vietnamese Restaurant   0.1
# 2        Mexican Restaurant   0.1
#
#
# ----Archway----
#                 venue  freq
# 0  Italian Restaurant  0.25
# 1    Kebab Restaurant  0.12
# 2    Asian Restaurant  0.12
#
#
# ----Arnos Grove----
#                    venue  freq
# 0     Chinese Restaurant   1.0
# 1      Afghan Restaurant   0.0
# 2  Portuguese Restaurant   0.0
#
#
# ----Balham----
#                  venue  freq
# 0    Indian Restaurant   0.3
# 1   Italian Restaurant   0.2
# 2  Moroccan Restaurant   0.1
#
#
# ----Bankside----
#                    venue  freq
# 0     Italian Restaurant  0.16
# 1  Portuguese Restaurant  0.11
# 2     Spanish Restaurant  0.11
#
#
# ----Barbican----
#                 venue  freq
# 0   French Restaurant   0.3
# 1  Italian Restaurant   0.2
# 2  English Restaurant   0.1
#
#
# ----Barking----
#                    venue  freq
# 0   Fast Food Restaurant  0.67
# 1  Portuguese Restaurant  0.33
# 2      Korean Restaurant  0.00
#
#
# ----Barnehurst----
#                        venue  freq
# 0           Asian Restaurant   0.5
# 1  Middle Eastern Restaurant   0.5
# 2          Afghan Restaurant   0.0
#
#
# ----Barnes----
#                venue  freq
# 0    Thai Restaurant   0.5
# 1         Restaurant   0.5
# 2  Afghan Restaurant   0.0
#
#
# ----Barnet ----
#                 venue  freq
# 0  Italian Restaurant  0.25
# 1          Restaurant  0.25
# 2   Indian Restaurant  0.12
#
#
# ----Barnsbury----
#                   venue  freq
# 0  Ethiopian Restaurant  0.50
# 1    Chinese Restaurant  0.25
# 2  Caucasian Restaurant  0.25
#
#
# ----Battersea----
#                    venue  freq
# 0  Portuguese Restaurant  0.14
# 1    Japanese Restaurant  0.14
# 2       Asian Restaurant  0.14
#
#
# ----Bayswater----
#                 venue  freq
# 0  Chinese Restaurant  0.14
# 1  Persian Restaurant  0.11
# 2    Greek Restaurant  0.11
#
#
# ----Beckenham----
#                       venue  freq
# 0        Italian Restaurant  0.36
# 1  Mediterranean Restaurant  0.18
# 2         Indian Restaurant  0.18
#
#
# ----Beckton----
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1     Afghan Restaurant   0.0
# 2     Korean Restaurant   0.0
#
#
# ----Becontree----
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1     Afghan Restaurant   0.0
# 2     Korean Restaurant   0.0
#
#
# ----Beddington----
#                venue  freq
# 0  Indian Restaurant   1.0
# 1  Afghan Restaurant   0.0
# 2  Korean Restaurant   0.0
#
#
# ----Bedford Park----
#                       venue  freq
# 0  Mediterranean Restaurant   0.5
# 1         French Restaurant   0.5
# 2         Afghan Restaurant   0.0
#
#
# ----Belgravia----
#                 venue  freq
# 0   Indian Restaurant  0.14
# 1  Seafood Restaurant  0.14
# 2   French Restaurant  0.14
#
#
# ----Bellingham----
#                   venue  freq
# 0    Turkish Restaurant   0.5
# 1  Fast Food Restaurant   0.5
# 2     Afghan Restaurant   0.0
#
#
# ----Belmont----
#                 venue  freq
# 0    Asian Restaurant  0.67
# 1  Chinese Restaurant  0.33
# 2   Afghan Restaurant  0.00
#
#
# ----Belsize Park----
#                 venue  freq
# 0  Italian Restaurant  0.33
# 1    Tapas Restaurant  0.11
# 2   Indian Restaurant  0.11
#
#
# ----Belvedere----
#                          venue  freq
# 0            Indian Restaurant   0.5
# 1  Eastern European Restaurant   0.5
# 2            Afghan Restaurant   0.0
#
#
# ----Bermondsey----
#                    venue  freq
# 0       Ramen Restaurant  0.33
# 1  Indonesian Restaurant  0.33
# 2   Brazilian Restaurant  0.33
#
#
# ----Bethnal Green----
#                   venue  freq
# 0    Italian Restaurant   0.1
# 1   Japanese Restaurant   0.1
# 2  Fast Food Restaurant   0.1
#
#
# ----Bexley ----
#                   venue  freq
# 0  Fast Food Restaurant   0.2
# 1     Indian Restaurant   0.2
# 2      Greek Restaurant   0.2
#
#
# ----Blackfriars----
#                 venue  freq
# 0  Italian Restaurant  0.27
# 1  Falafel Restaurant  0.13
# 2    Sushi Restaurant  0.13
#
#
# ----Blackheath----
#                venue  freq
# 0  Indian Restaurant  0.14
# 1  French Restaurant  0.14
# 2         Restaurant  0.14
#
#
# ----Blackheath Royal Standard----
#                   venue  freq
# 0    Chinese Restaurant   0.5
# 1  Fast Food Restaurant   0.5
# 2     Afghan Restaurant   0.0
#
#
# ----Blackwall----
#                 venue  freq
# 0  Italian Restaurant   1.0
# 1   Afghan Restaurant   0.0
# 2   Korean Restaurant   0.0
#
#
# ----Blendon----
#                venue  freq
# 0  Indian Restaurant   1.0
# 1  Afghan Restaurant   0.0
# 2  Korean Restaurant   0.0
#
#
# ----Bloomsbury----
#                  venue  freq
# 0   Italian Restaurant  0.25
# 1  Szechuan Restaurant  0.12
# 2   Turkish Restaurant  0.12
#
#
# ----Bow----
#                    venue  freq
# 0     Turkish Restaurant   1.0
# 1      Afghan Restaurant   0.0
# 2  Portuguese Restaurant   0.0
#
#
# ----Bowes Park----
#                venue  freq
# 0   Greek Restaurant   1.0
# 1  Afghan Restaurant   0.0
# 2  Korean Restaurant   0.0
#
#
# ----Brent Cross----
#                    venue  freq
# 0       Asian Restaurant  0.33
# 1       Sushi Restaurant  0.33
# 2  Portuguese Restaurant  0.33
#
#
# ----Brimsdown----
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1     Afghan Restaurant   0.0
# 2     Korean Restaurant   0.0
#
#
# ----Brixton----
#                   venue  freq
# 0  Caribbean Restaurant  0.18
# 1    Mexican Restaurant  0.09
# 2     Indian Restaurant  0.06
#
#
# ----Brockley----
#                 venue  freq
# 0    Malay Restaurant   0.5
# 1  Chinese Restaurant   0.5
# 2   Afghan Restaurant   0.0
#
#
# ----Bromley----
#                    venue  freq
# 0  Portuguese Restaurant  0.33
# 1   Fast Food Restaurant  0.17
# 2       Asian Restaurant  0.17
#
#
# ----Bromley Common----
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1     Afghan Restaurant   0.0
# 2     Korean Restaurant   0.0
#
#
# ----Brondesbury----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.14
# 1           Asian Restaurant  0.14
# 2       Brazilian Restaurant  0.14
#
#
# ----Burnt Oak----
#                          venue  freq
# 0  Eastern European Restaurant   1.0
# 1            Afghan Restaurant   0.0
# 2        Portuguese Restaurant   0.0
#
#
# ----Burroughs----
#                  venue  freq
# 0    Korean Restaurant  0.33
# 1  Japanese Restaurant  0.33
# 2     Sushi Restaurant  0.33
#
#
# ----Camberwell----
#                        venue  freq
# 0      Vietnamese Restaurant  0.17
# 1  Middle Eastern Restaurant  0.11
# 2          Indian Restaurant  0.11
#
#
# ----Cambridge Heath----
#                venue  freq
# 0  Indian Restaurant  0.11
# 1   Arepa Restaurant  0.11
# 2  Veneto Restaurant  0.11
#
#
# ----Camden Town----
#                            venue  freq
# 0             Italian Restaurant  0.21
# 1          Vietnamese Restaurant  0.11
# 2  Vegetarian / Vegan Restaurant  0.11
#
#
# ----Canary Wharf----
#                 venue  freq
# 0    Sushi Restaurant  0.12
# 1  Italian Restaurant  0.12
# 2  Turkish Restaurant  0.08
#
#
# ----Canning Town----
#                   venue  freq
# 0    Turkish Restaurant  0.50
# 1    Italian Restaurant  0.25
# 2  Fast Food Restaurant  0.25
#
#
# ----Canonbury----
#                         venue  freq
# 0          Italian Restaurant  0.33
# 1   Middle Eastern Restaurant  0.33
# 2  Modern European Restaurant  0.33
#
#
# ----Castelnau----
#                venue  freq
# 0  French Restaurant   1.0
# 1  Afghan Restaurant   0.0
# 2  Korean Restaurant   0.0
#
#
# ----Catford----
#                    venue  freq
# 0     Italian Restaurant  0.33
# 1  Portuguese Restaurant  0.17
# 2    Japanese Restaurant  0.17
#
#
# ----Chadwell Heath----
#                   venue  freq
# 0     Indian Restaurant   0.5
# 1  Fast Food Restaurant   0.5
# 2     Afghan Restaurant   0.0
#
#
# ----Chalk Farm----
#                 venue  freq
# 0  Italian Restaurant   0.2
# 1   French Restaurant   0.1
# 2          Restaurant   0.1
#
#
# ----Charing Cross----
#                    venue  freq
# 0             Restaurant  0.20
# 1     Italian Restaurant  0.13
# 2  Portuguese Restaurant  0.07
#
#
# ----Charlton----
#                    venue  freq
# 0        Thai Restaurant   1.0
# 1      Afghan Restaurant   0.0
# 2  Portuguese Restaurant   0.0
#
#
# ----Chase Cross----
#                    venue  freq
# 0     Seafood Restaurant   1.0
# 1      Afghan Restaurant   0.0
# 2  Portuguese Restaurant   0.0
#
#
# ----Cheam----
#                  venue  freq
# 0   Italian Restaurant  0.38
# 1    Indian Restaurant  0.12
# 2  American Restaurant  0.12
#
#
# ----Chelsea----
#                  venue  freq
# 0    French Restaurant  0.20
# 1  Japanese Restaurant  0.13
# 2   Italian Restaurant  0.13
#
#
# ----Chelsfield----
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1     Afghan Restaurant   0.0
# 2     Korean Restaurant   0.0
#
#
# ----Chinatown----
#                  venue  freq
# 0   Seafood Restaurant  0.12
# 1  Japanese Restaurant  0.12
# 2    Indian Restaurant  0.08
#
#
# ----Chingford----
#                 venue  freq
# 0  Italian Restaurant   0.5
# 1     Thai Restaurant   0.5
# 2   Afghan Restaurant   0.0
#
#
# ----Chislehurst----
#                 venue  freq
# 0  Italian Restaurant   0.5
# 1   Indian Restaurant   0.5
# 2   Afghan Restaurant   0.0
#
#
# ----Chiswick----
#                    venue  freq
# 0     Italian Restaurant  0.21
# 1  Vietnamese Restaurant  0.14
# 2       Sushi Restaurant  0.14
#
#
# ----Church End----
#                  venue  freq
# 0   Turkish Restaurant  0.20
# 1    Indian Restaurant  0.20
# 2  Japanese Restaurant  0.13
#
#
# ----Clapham----
#                  venue  freq
# 0           Restaurant  0.14
# 1  Japanese Restaurant  0.07
# 2   Italian Restaurant  0.07
#
#
# ----Clerkenwell----
#                    venue  freq
# 0     Italian Restaurant  0.13
# 1      French Restaurant  0.13
# 2  Vietnamese Restaurant  0.09
#
#
# ----Cockfosters----
#                 venue  freq
# 0  Turkish Restaurant   0.4
# 1    Greek Restaurant   0.4
# 2  Italian Restaurant   0.2
#
#
# ----Colindale----
#                   venue  freq
# 0    Chinese Restaurant   0.5
# 1  Fast Food Restaurant   0.5
# 2     Afghan Restaurant   0.0
#
#
# ----Collier Row----
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1     Afghan Restaurant   0.0
# 2     Korean Restaurant   0.0
#
#
# ----Colliers Wood----
#                    venue  freq
# 0  Portuguese Restaurant  0.17
# 1    American Restaurant  0.17
# 2   Fast Food Restaurant  0.17
#
#
# ----Colney Hatch----
#                venue  freq
# 0  Indian Restaurant   1.0
# 1  Afghan Restaurant   0.0
# 2  Korean Restaurant   0.0
#
#
# ----Coney Hall----
#                    venue  freq
# 0             Restaurant   1.0
# 1      Afghan Restaurant   0.0
# 2  Portuguese Restaurant   0.0
#
#
# ----Coombe----
#                 venue  freq
# 0    Malay Restaurant  0.11
# 1  Italian Restaurant  0.11
# 2  Spanish Restaurant  0.11
#
#
# ----Coulsdon----
#                 venue  freq
# 0  Italian Restaurant   1.0
# 1   Afghan Restaurant   0.0
# 2   Korean Restaurant   0.0
#
#
# ----Covent Garden----
#                  venue  freq
# 0           Restaurant  0.13
# 1  Japanese Restaurant  0.09
# 2   Italian Restaurant  0.09
#
#
# ----Cowley----
#                    venue  freq
# 0             Restaurant   1.0
# 1      Afghan Restaurant   0.0
# 2  Portuguese Restaurant   0.0
#
#
# ----Cranford----
#                    venue  freq
# 0   Fast Food Restaurant  0.29
# 1             Restaurant  0.29
# 2  Portuguese Restaurant  0.14
#
#
# ----Cranham----
#                   venue  freq
# 0     Indian Restaurant   0.5
# 1  Fast Food Restaurant   0.5
# 2     Afghan Restaurant   0.0
#
#
# ----Crayford----
#                       venue  freq
# 0     Portuguese Restaurant  0.33
# 1        Italian Restaurant  0.33
# 2  Mediterranean Restaurant  0.33
#
#
# ----Cricklewood----
#                   venue  freq
# 0  Fast Food Restaurant  0.71
# 1     Afghan Restaurant  0.14
# 2    Italian Restaurant  0.14
#
#
# ----Crofton Park----
#                    venue  freq
# 0       Malay Restaurant   1.0
# 1      Afghan Restaurant   0.0
# 2  Portuguese Restaurant   0.0
#
#
# ----Crook Log----
#                  venue  freq
# 0   English Restaurant   1.0
# 1    Korean Restaurant   0.0
# 2  Lebanese Restaurant   0.0
#
#
# ----Crouch End----
#                  venue  freq
# 0           Restaurant  0.11
# 1      Thai Restaurant  0.11
# 2  Japanese Restaurant  0.11
#
#
# ----Croydon----
#                 venue  freq
# 0    Malay Restaurant  0.11
# 1  Italian Restaurant  0.11
# 2  Spanish Restaurant  0.11

# %% [markdown]
# #### the following dataframe with the above results for each neighborhood would be developed:

# %%
# A function to sort the venues in descending order
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
#Creating a new dataframe and displaying the top 10 restaurants based on occurance and cuisine for each neighborhood
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = London_grouped['Neighborhood']


for ind in np.arange(London_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(London_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#   Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0        Acton  Fast Food Restaurant    Chinese Restaurant
# 1    Addington    English Restaurant   Xinjiang Restaurant
# 2   Addiscombe  Fast Food Restaurant    Chinese Restaurant
# 3  Albany Park     Indian Restaurant   Xinjiang Restaurant
# 4      Aldgate     Indian Restaurant            Restaurant
#
#          3rd Most Common Venue        4th Most Common Venue  \
# 0          Xinjiang Restaurant  Eastern European Restaurant
# 1  Eastern European Restaurant           Italian Restaurant
# 2          Xinjiang Restaurant  Eastern European Restaurant
# 3  Eastern European Restaurant           Italian Restaurant
# 4           Italian Restaurant    Middle Eastern Restaurant
#
#   5th Most Common Venue  6th Most Common Venue  7th Most Common Venue  \
# 0    Italian Restaurant     Israeli Restaurant  Indonesian Restaurant
# 1    Israeli Restaurant  Indonesian Restaurant      Indian Restaurant
# 2    Italian Restaurant     Israeli Restaurant  Indonesian Restaurant
# 3    Israeli Restaurant  Indonesian Restaurant       Hunan Restaurant
# 4       Thai Restaurant       Asian Restaurant       Sushi Restaurant
#
#    8th Most Common Venue 9th Most Common Venue    10th Most Common Venue
# 0      Indian Restaurant      Hunan Restaurant      Himalayan Restaurant
# 1       Hunan Restaurant  Himalayan Restaurant          Greek Restaurant
# 2      Indian Restaurant      Hunan Restaurant      Himalayan Restaurant
# 3   Himalayan Restaurant      Greek Restaurant    Gluten-free Restaurant
# 4  Vietnamese Restaurant  Fast Food Restaurant  Mediterranean Restaurant

# %% [markdown]
# ##  Neighborhoods Custering by Utilizing K-means:

# %% [markdown]
# #### The best K-means would be determined as follow:

# %%
# Creating new dataframe to determine best k value by dropping first column
London_clustering_testing = London_grouped.drop('Neighborhood', 1)

# %%
def plot(x, y, xlabel, ylabel):
    plt.figure(figsize=(20,10))
    plt.plot(np.arange(2, x), y, 'o-')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(np.arange(2, x))
    plt.show()
    
indices = []
scores = []
max_range = 10

for kclusters in range(2, max_range) :
    
    # Run k-means clustering
    lct = London_clustering_testing
    kmeans = KMeans(n_clusters = kclusters, init = 'k-means++', random_state = 0).fit_predict(lct)
    
    # Gets the score for the clustering operation performed
    score = silhouette_score(lct, kmeans)
    
    # Appending the index and score to the respective lists
    indices.append(kclusters)
    scores.append(score)
    

plot(max_range, scores, "No. of clusters", "Silhouette Score")

# %%
opt = np.argmax(scores) + 2 # Finds the optimal value
opt
# Out:
# 9

# %%
# set number of clusters
kclusters = opt

London_grouped_clustering = London_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(London_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([6, 4, 1, 2, 0, 0, 2, 1, 0, 0], dtype=int32)

# %% [markdown]
# #### Based on the above results a new dataframe would be created to indicates the clusters along with the top 10 venues for each neighborhood.

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

London_merged = London_restaurants

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
London_merged = London_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
London_merged.fillna(0)
London_merged.head() # check the last columns!
# Out:
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 10        Acton              51.508140               -0.273261
# 17        Acton              51.508140               -0.273261
# 27    Addington              51.358637               -0.031635
# 35   Addiscombe              51.379692               -0.074282
# 37   Addiscombe              51.379692               -0.074282
#
#                          Venue  Venue Latitude  Venue Longitude  \
# 10           Amigo's Peri Peri       51.508396        -0.274561
# 17      North China Restaurant       51.508251        -0.277435
# 27  The Cricketers (Harvester)       51.357833        -0.032844
# 35                         KFC       51.380105        -0.073570
# 37                    Brothers       51.379690        -0.074347
#
#           Venue Category  Cluster Labels 1st Most Common Venue  \
# 10  Fast Food Restaurant               6  Fast Food Restaurant
# 17    Chinese Restaurant               6  Fast Food Restaurant
# 27    English Restaurant               4    English Restaurant
# 35  Fast Food Restaurant               1  Fast Food Restaurant
# 37  Fast Food Restaurant               1  Fast Food Restaurant
#
#    2nd Most Common Venue        3rd Most Common Venue  \
# 10    Chinese Restaurant          Xinjiang Restaurant
# 17    Chinese Restaurant          Xinjiang Restaurant
# 27   Xinjiang Restaurant  Eastern European Restaurant
# 35    Chinese Restaurant          Xinjiang Restaurant
# 37    Chinese Restaurant          Xinjiang Restaurant
#
#           4th Most Common Venue 5th Most Common Venue  6th Most Common Venue  \
# 10  Eastern European Restaurant    Italian Restaurant     Israeli Restaurant
# 17  Eastern European Restaurant    Italian Restaurant     Israeli Restaurant
# 27           Italian Restaurant    Israeli Restaurant  Indonesian Restaurant
# 35  Eastern European Restaurant    Italian Restaurant     Israeli Restaurant
# 37  Eastern European Restaurant    Italian Restaurant     Israeli Restaurant
#
#     7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 10  Indonesian Restaurant     Indian Restaurant      Hunan Restaurant
# 17  Indonesian Restaurant     Indian Restaurant      Hunan Restaurant
# 27      Indian Restaurant      Hunan Restaurant  Himalayan Restaurant
# 35  Indonesian Restaurant     Indian Restaurant      Hunan Restaurant
# 37  Indonesian Restaurant     Indian Restaurant      Hunan Restaurant
#
#    10th Most Common Venue
# 10   Himalayan Restaurant
# 17   Himalayan Restaurant
# 27       Greek Restaurant
# 35   Himalayan Restaurant
# 37   Himalayan Restaurant

# %% [markdown]
# #### Number of venues belonging to each cluster:

# %%
London_merged['Cluster Labels'].value_counts()
# Out:
# 0    640
# 1     24
# 2     10
# 6      9
# 8      7
# 3      4
# 5      3
# 4      2
# 7      1
# Name: Cluster Labels, dtype: int64

# %% [markdown]
# ### Map of clusters:
# ### The following codes would result in a map being generated to indicate each cluster for better visualization.

# %%
# create map
map_clusters = folium.Map(location=[lat_e, long_e], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster, vc in zip(London_merged['Venue Latitude'], London_merged['Venue Longitude'], London_merged['Venue'], London_merged['Cluster Labels'], London_merged['Venue Category']):
    label = folium.Popup(str(poi) +' (' +str(vc) + ') ['+ str(cluster)+']', parse_html=True)

    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
    
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Analysing the clusters
#
# #### Now,  each cluster would be examined and  the discriminating restaurants would be distinguished by each cluster. Based on the restaurants, we can then assign a name to each cluster.

# %% [markdown]
# ### Cluster 1

# %%
c1 = London_merged.loc[London_merged['Cluster Labels'] == 0, London_merged.columns[[0]+list(range(8, London_merged.shape[1]))]]
c1.drop_duplicates()
# Out:
#          Neighborhood     1st Most Common Venue      2nd Most Common Venue  \
# 55            Aldgate         Indian Restaurant                 Restaurant
# 147           Aldwych                Restaurant         English Restaurant
# 265             Angel         Indian Restaurant      Vietnamese Restaurant
# 332           Archway        Italian Restaurant           Kebab Restaurant
# 382            Balham         Indian Restaurant         Italian Restaurant
# 441          Bankside        Italian Restaurant         Spanish Restaurant
# 498          Barbican         French Restaurant         Italian Restaurant
# 580        Barnehurst          Asian Restaurant  Middle Eastern Restaurant
# 616           Barnet         Italian Restaurant                 Restaurant
# 640         Barnsbury      Ethiopian Restaurant       Caucasian Restaurant
# 669         Battersea       Japanese Restaurant         Italian Restaurant
# 697         Bayswater        Chinese Restaurant           Greek Restaurant
# 795         Beckenham        Italian Restaurant          Indian Restaurant
# 866      Bedford Park  Mediterranean Restaurant          French Restaurant
# 888         Belgravia        Seafood Restaurant        Japanese Restaurant
# 932           Belmont          Asian Restaurant         Chinese Restaurant
# 954      Belsize Park        Italian Restaurant          French Restaurant
# 1000       Bermondsey      Brazilian Restaurant           Ramen Restaurant
# 1030    Bethnal Green       Japanese Restaurant          French Restaurant
# 1086          Bexley         Italian Restaurant          Indian Restaurant
# 1113      Blackfriars        Italian Restaurant         Falafel Restaurant
# 1186       Blackheath      Himalayan Restaurant          French Restaurant
# 1255       Bloomsbury        Italian Restaurant         Chinese Restaurant
# 1353       Bowes Park          Greek Restaurant        Xinjiang Restaurant
# 1986         Himalayan Restaurant            Greek Restaurant
# 2019         Himalayan Restaurant            Greek Restaurant
# 2030  Eastern European Restaurant      Gluten-free Restaurant
# 2080         Caribbean Restaurant        Brazilian Restaurant
# 2154           Spanish Restaurant          Persian Restaurant
# 2226         Himalayan Restaurant            Greek Restaurant
# 2236         Himalayan Restaurant            Greek Restaurant
# 2240           Falafel Restaurant        Fast Food Restaurant
# 2261        Vietnamese Restaurant         American Restaurant
# 2319           Chinese Restaurant            Malay Restaurant
# 2423         Himalayan Restaurant            Greek Restaurant
# 2439             Greek Restaurant      Gluten-free Restaurant
# 2446           Seafood Restaurant          Persian Restaurant
# 2498           Chinese Restaurant                  Restaurant
# 2534            French Restaurant          English Restaurant
# 2625                   Restaurant      Gluten-free Restaurant
# 2726             Hunan Restaurant        Himalayan Restaurant
# 2763           Falafel Restaurant           French Restaurant
# 2799         Caribbean Restaurant      Gluten-free Restaurant
# 2832          Peruvian Restaurant       Portuguese Restaurant
# 2936           Falafel Restaurant           French Restaurant
# 2966         Himalayan Restaurant            Greek Restaurant
# 3029         Himalayan Restaurant            Greek Restaurant
# 3050          American Restaurant            Tapas Restaurant
# 3114         Caribbean Restaurant      Gluten-free Restaurant

# %% [markdown]
# ### Cluster 2

# %%
c2 = London_merged.loc[London_merged['Cluster Labels'] == 1, London_merged.columns[[0]+list(range(8, London_merged.shape[1]))]]
c2.drop_duplicates()
# Out:
#         Neighborhood 1st Most Common Venue  2nd Most Common Venue  \
# 35        Addiscombe  Fast Food Restaurant     Chinese Restaurant
# 257          Anerley  Fast Food Restaurant    Xinjiang Restaurant
# 557          Barking  Fast Food Restaurant  Portuguese Restaurant
# 843          Beckton  Fast Food Restaurant    Xinjiang Restaurant
# 854        Becontree  Fast Food Restaurant    Xinjiang Restaurant
# 1432       Brimsdown  Fast Food Restaurant    Xinjiang Restaurant
# 1606  Bromley Common  Fast Food Restaurant    Xinjiang Restaurant
# 2064  Chadwell Heath     Indian Restaurant   Fast Food Restaurant
# 2311      Chelsfield  Fast Food Restaurant    Xinjiang Restaurant
# 2759     Collier Row  Fast Food Restaurant    Xinjiang Restaurant
# 2961         Cranham     Indian Restaurant   Fast Food Restaurant
# 2992     Cricklewood  Fast Food Restaurant      Afghan Restaurant
#
#             3rd Most Common Venue        4th Most Common Venue  \
# 35            Xinjiang Restaurant  Eastern European Restaurant
# 257   Eastern European Restaurant           Italian Restaurant
# 557           Xinjiang Restaurant  Eastern European Restaurant
# 843   Eastern European Restaurant           Italian Restaurant
# 854   Eastern European Restaurant           Italian Restaurant
# 1432  Eastern European Restaurant           Italian Restaurant
# 1606  Eastern European Restaurant           Italian Restaurant
# 2064          Xinjiang Restaurant  Eastern European Restaurant
# 2311  Eastern European Restaurant           Italian Restaurant
# 2759  Eastern European Restaurant           Italian Restaurant
# 2961          Xinjiang Restaurant  Eastern European Restaurant
# 2992           Italian Restaurant  Eastern European Restaurant
#
#      5th Most Common Venue  6th Most Common Venue  7th Most Common Venue  \
# 35      Italian Restaurant     Israeli Restaurant  Indonesian Restaurant
# 257     Israeli Restaurant  Indonesian Restaurant      Indian Restaurant
# 557     Italian Restaurant     Israeli Restaurant  Indonesian Restaurant
# 843     Israeli Restaurant  Indonesian Restaurant      Indian Restaurant
# 854     Israeli Restaurant  Indonesian Restaurant      Indian Restaurant
# 1432    Israeli Restaurant  Indonesian Restaurant      Indian Restaurant
# 1606    Israeli Restaurant  Indonesian Restaurant      Indian Restaurant
# 2064    Italian Restaurant     Israeli Restaurant  Indonesian Restaurant
# 2311    Israeli Restaurant  Indonesian Restaurant      Indian Restaurant
# 2759    Israeli Restaurant  Indonesian Restaurant      Indian Restaurant
# 2961    Italian Restaurant     Israeli Restaurant  Indonesian Restaurant
# 2992    Israeli Restaurant  Indonesian Restaurant      Indian Restaurant
#
#      8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 35       Indian Restaurant      Hunan Restaurant   Himalayan Restaurant
# 257       Hunan Restaurant  Himalayan Restaurant       Greek Restaurant
# 557      Indian Restaurant      Hunan Restaurant   Himalayan Restaurant
# 843       Hunan Restaurant  Himalayan Restaurant       Greek Restaurant
# 854       Hunan Restaurant  Himalayan Restaurant       Greek Restaurant
# 1432      Hunan Restaurant  Himalayan Restaurant       Greek Restaurant
# 1606      Hunan Restaurant  Himalayan Restaurant       Greek Restaurant
# 2064      Hunan Restaurant  Himalayan Restaurant       Greek Restaurant
# 2311      Hunan Restaurant  Himalayan Restaurant       Greek Restaurant
# 2759      Hunan Restaurant  Himalayan Restaurant       Greek Restaurant
# 2961      Hunan Restaurant  Himalayan Restaurant       Greek Restaurant
# 2992      Hunan Restaurant  Himalayan Restaurant       Greek Restaurant

# %% [markdown]
#  ### Cluster 3

# %%
c3 = London_merged.loc[London_merged['Cluster Labels'] == 2, London_merged.columns[[0]+list(range(8, London_merged.shape[1]))]]
c3.drop_duplicates()
# Out:
#       Neighborhood        1st Most Common Venue 2nd Most Common Venue  \
# 45     Albany Park            Indian Restaurant   Xinjiang Restaurant
# 249       Alperton            Indian Restaurant      Asian Restaurant
# 864     Beddington            Indian Restaurant   Xinjiang Restaurant
# 993      Belvedere  Eastern European Restaurant     Indian Restaurant
# 1243       Blendon            Indian Restaurant   Xinjiang Restaurant
# 2785  Colney Hatch            Indian Restaurant   Xinjiang Restaurant
#
#             3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 45    Eastern European Restaurant    Italian Restaurant    Israeli Restaurant
# 249     Middle Eastern Restaurant   Xinjiang Restaurant    English Restaurant
# 864   Eastern European Restaurant    Italian Restaurant    Israeli Restaurant
# 993           Xinjiang Restaurant    Italian Restaurant    Israeli Restaurant
# 1243  Eastern European Restaurant    Italian Restaurant    Israeli Restaurant
# 2785  Eastern European Restaurant    Italian Restaurant    Israeli Restaurant
#
#       6th Most Common Venue 7th Most Common Venue  8th Most Common Venue  \
# 45    Indonesian Restaurant      Hunan Restaurant   Himalayan Restaurant
# 249      Italian Restaurant    Israeli Restaurant  Indonesian Restaurant
# 864   Indonesian Restaurant      Hunan Restaurant   Himalayan Restaurant
# 993   Indonesian Restaurant      Hunan Restaurant   Himalayan Restaurant
# 1243  Indonesian Restaurant      Hunan Restaurant   Himalayan Restaurant
# 2785  Indonesian Restaurant      Hunan Restaurant   Himalayan Restaurant
#
#      9th Most Common Venue  10th Most Common Venue
# 45        Greek Restaurant  Gluten-free Restaurant
# 249       Hunan Restaurant    Himalayan Restaurant
# 864       Greek Restaurant  Gluten-free Restaurant
# 993       Greek Restaurant  Gluten-free Restaurant
# 1243      Greek Restaurant  Gluten-free Restaurant
# 2785      Greek Restaurant  Gluten-free Restaurant

# %% [markdown]
# ### Cluster 4

# %%
c4 = London_merged.loc[London_merged['Cluster Labels'] == 3, London_merged.columns[[0]+list(range(8, London_merged.shape[1]))]]
c4.drop_duplicates()
# Out:
#      Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 587        Barnes            Restaurant       Thai Restaurant
# 2795   Coney Hall            Restaurant   Xinjiang Restaurant
# 2935       Cowley            Restaurant   Xinjiang Restaurant
#
#             3rd Most Common Venue   4th Most Common Venue  \
# 587           Xinjiang Restaurant  Gluten-free Restaurant
# 2795  Eastern European Restaurant      Italian Restaurant
# 2935  Eastern European Restaurant      Italian Restaurant
#
#      5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 587     English Restaurant   Ethiopian Restaurant    Falafel Restaurant
# 2795    Israeli Restaurant  Indonesian Restaurant     Indian Restaurant
# 2935    Israeli Restaurant  Indonesian Restaurant     Indian Restaurant
#
#      8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 587   Fast Food Restaurant     French Restaurant       Greek Restaurant
# 2795      Hunan Restaurant  Himalayan Restaurant       Greek Restaurant
# 2935      Hunan Restaurant  Himalayan Restaurant       Greek Restaurant

# %% [markdown]
# ### Cluster 5

# %%
c5 = London_merged.loc[London_merged['Cluster Labels'] == 4, London_merged.columns[[0]+list(range(8, London_merged.shape[1]))]]
c5.drop_duplicates()
# Out:
#      Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 27      Addington    English Restaurant   Xinjiang Restaurant
# 3042    Crook Log    English Restaurant   Xinjiang Restaurant
#
#             3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 27    Eastern European Restaurant    Italian Restaurant    Israeli Restaurant
# 3042  Eastern European Restaurant    Italian Restaurant    Israeli Restaurant
#
#       6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 27    Indonesian Restaurant     Indian Restaurant      Hunan Restaurant
# 3042  Indonesian Restaurant     Indian Restaurant      Hunan Restaurant
#
#      9th Most Common Venue 10th Most Common Venue
# 27    Himalayan Restaurant       Greek Restaurant
# 3042  Himalayan Restaurant       Greek Restaurant

# %% [markdown]
# ### Cluster 6

# %%
c6 = London_merged.loc[London_merged['Cluster Labels'] == 5, London_merged.columns[[0]+list(range(8, London_merged.shape[1]))]]
c6.drop_duplicates()
# Out:
#      Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 1226    Blackwall    Italian Restaurant   Xinjiang Restaurant
# 2830     Coulsdon    Italian Restaurant   Xinjiang Restaurant
#
#             3rd Most Common Venue 4th Most Common Venue  \
# 1226  Eastern European Restaurant    Israeli Restaurant
# 2830  Eastern European Restaurant    Israeli Restaurant
#
#       5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 1226  Indonesian Restaurant     Indian Restaurant      Hunan Restaurant
# 2830  Indonesian Restaurant     Indian Restaurant      Hunan Restaurant
#
#      8th Most Common Venue 9th Most Common Venue  10th Most Common Venue
# 1226  Himalayan Restaurant      Greek Restaurant  Gluten-free Restaurant
# 2830  Himalayan Restaurant      Greek Restaurant  Gluten-free Restaurant

# %% [markdown]
# ### Cluster 7

# %%
c7 = London_merged.loc[London_merged['Cluster Labels'] == 6, London_merged.columns[[0]+list(range(8, London_merged.shape[1]))]]
c7.drop_duplicates()
# Out:
#                    Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 10                        Acton  Fast Food Restaurant    Chinese Restaurant
# 376                 Arnos Grove    Chinese Restaurant   Xinjiang Restaurant
# 1218  Blackheath Royal Standard  Fast Food Restaurant    Chinese Restaurant
# 1542                   Brockley      Malay Restaurant    Chinese Restaurant
# 2750                  Colindale  Fast Food Restaurant    Chinese Restaurant
#
#             3rd Most Common Venue        4th Most Common Venue  \
# 10            Xinjiang Restaurant  Eastern European Restaurant
# 376   Eastern European Restaurant           Italian Restaurant
# 1218          Xinjiang Restaurant  Eastern European Restaurant
# 1542          Xinjiang Restaurant           English Restaurant
# 2750          Xinjiang Restaurant  Eastern European Restaurant
#
#      5th Most Common Venue  6th Most Common Venue  7th Most Common Venue  \
# 10      Italian Restaurant     Israeli Restaurant  Indonesian Restaurant
# 376     Israeli Restaurant  Indonesian Restaurant      Indian Restaurant
# 1218    Italian Restaurant     Israeli Restaurant  Indonesian Restaurant
# 1542    Italian Restaurant     Israeli Restaurant  Indonesian Restaurant
# 2750    Italian Restaurant     Israeli Restaurant  Indonesian Restaurant
#
#      8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 10       Indian Restaurant      Hunan Restaurant   Himalayan Restaurant
# 376       Hunan Restaurant  Himalayan Restaurant       Greek Restaurant
# 1218     Indian Restaurant      Hunan Restaurant   Himalayan Restaurant
# 1542     Indian Restaurant      Hunan Restaurant   Himalayan Restaurant
# 2750     Indian Restaurant      Hunan Restaurant   Himalayan Restaurant

# %% [markdown]
# ### Cluster 8

# %%
c8 = London_merged.loc[London_merged['Cluster Labels'] == 7, London_merged.columns[[0]+list(range(8, London_merged.shape[1]))]]
c8.drop_duplicates()
# Out:
#      Neighborhood        1st Most Common Venue 2nd Most Common Venue  \
# 1653    Burnt Oak  Eastern European Restaurant   Xinjiang Restaurant
#
#      3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 1653    Italian Restaurant    Israeli Restaurant  Indonesian Restaurant
#
#      6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 1653     Indian Restaurant      Hunan Restaurant  Himalayan Restaurant
#
#      9th Most Common Venue  10th Most Common Venue
# 1653      Greek Restaurant  Gluten-free Restaurant

# %% [markdown]
# ### Cluster 9

# %%
c9 = London_merged.loc[London_merged['Cluster Labels'] == 8, London_merged.columns[[0]+list(range(8, London_merged.shape[1]))]]
c9.drop_duplicates()
# Out:
#       Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 918     Bellingham    Turkish Restaurant  Fast Food Restaurant
# 1331           Bow    Turkish Restaurant   Xinjiang Restaurant
# 1959  Canning Town    Turkish Restaurant    Italian Restaurant
#
#             3rd Most Common Venue        4th Most Common Venue  \
# 918           Xinjiang Restaurant  Eastern European Restaurant
# 1331  Eastern European Restaurant           Italian Restaurant
# 1959         Fast Food Restaurant          Xinjiang Restaurant
#
#             5th Most Common Venue  6th Most Common Venue  \
# 918            Italian Restaurant     Israeli Restaurant
# 1331           Israeli Restaurant  Indonesian Restaurant
# 1959  Eastern European Restaurant     Israeli Restaurant
#
#       7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 918   Indonesian Restaurant     Indian Restaurant      Hunan Restaurant
# 1331      Indian Restaurant      Hunan Restaurant  Himalayan Restaurant
# 1959  Indonesian Restaurant     Indian Restaurant      Hunan Restaurant
#
#      10th Most Common Venue
# 918    Himalayan Restaurant
# 1331       Greek Restaurant
# 1959   Himalayan Restaurant

# %% [markdown]
# ### Results

# %% [markdown]
# Considering the clustering results we can approach the following:
#
# -	The most commom restaurants in each cluster have been located;
# -   The best boroughs to open a restaurant with a specefic cuisine (i.e., most favorite cuisine of the borough) can be choosen;
# -   The neighborhood in a specific cluster, can be choosen in order to open a restaurent which is the least common in that specific region, which would result in profitability and less competition;

# %% [markdown]
#    | Cluster | Most Common Restaurant     |
#    |---------|----------------------------|
#    |   1     | Italian Restaurant         |
#    |   2     | Fast Food Restaurant       |
#    |   3     | Indian Restaurant          |
#    |   4     | Restaurant                 |
#    |   5     | English Restaurant         |
#    |   6     | Italian Restaurant         |
#    |   7     | Fast Food Restaurant       |
#    |   8     | Eastern European Restaurant|
#    |   9     | Turkish Restaurant         |

# %% [markdown]
# ### Conclusion
#
# The presented work has been conducted based on a small sample cluster, for the sole purpose of depicting the program’s feasibility potential. It can further be extended into larger data sets, and as result, the program would result in more output results and findings. The outcomes would also provide the relevant information on the number and intensity of the restaurants in certain boroughs, which can be interpreted as which areas would be of higher demands in terms of the popular regions for the intended cuisine and leisure industry. Moreover, a number of other factors regarding these places can be included in order to distinguish or narrow down the results, such as the restaurants’ type (e.g., Italian, Asian, etc.) or hygiene rate.
